# %% [markdown]
# # Mercedes F1 Infringement Profile - Abstractive Summarization (Version 2)
#
# This notebook implements abstractive summarization (using DistilBART) for Mercedes F1 infringement documents with modified parameters.
#
# ## Objective:
# - Process all `no_footer_` files from the preprocessed dataset
# - Apply abstractive summarization model (DistilBART - smaller, memory-efficient) with updated parameters
# - Maintain temporal analysis (year-by-year summaries)
# - Generate abstractive summaries that create new sentences (not just extract)
#
# ## Input:
# - `pre_proc_op/` folder containing `no_footer_*.txt` files organized by year
#
# ## Output:
# - Console summaries for each year
# - Overall consolidated summary
# - Results saved to `distilbart_results_v2/` folder
#
# **Note:** Using DistilBART for better memory efficiency and stability (~260MB vs ~2.3GB for Pegasus).

# %%
# Import required libraries
import os
import re
from pathlib import Path
import warnings
warnings.filterwarnings('ignore')

# DistilBART implementation
from transformers import pipeline, AutoTokenizer, AutoModelForSeq2SeqLM
import torch

print("Libraries imported successfully")
# Out:
# Libraries imported successfully

# %%
# Configuration
processed_base_path = Path("pre_proc_op")
years = ["2020", "2021", "2022", "2023", "2024"]

# Model configuration (Version 2 - Modified)
# Options:
# - "sshleifer/distilbart-cnn-12-6" (smallest, ~260MB) - RECOMMENDED for stability
# - "facebook/bart-large-cnn" (medium, ~1.6GB)
# - "google/pegasus-xsum" (large, ~2.3GB) - may cause kernel crashes
MODEL_NAME = "sshleifer/distilbart-cnn-12-6"  # Smaller, memory-efficient abstractive summarization model
MAX_LENGTH = 768  # Maximum length for generated summary (increased from 512)
MIN_LENGTH = 100   # Minimum length for generated summary (increased from 50)
MAX_INPUT_LENGTH = 1024  # Max input tokens (will chunk if needed)

print("Configuration (Version 2):")
print(f"Processed base path: {processed_base_path}")
print(f"Years to analyze: {years}")
print(f"Model: {MODEL_NAME}")
print(f"Max summary length: {MAX_LENGTH}")
print(f"Min summary length: {MIN_LENGTH}")
# Out:
# Configuration (Version 2):
# Processed base path: pre_proc_op
# Years to analyze: ['2020', '2021', '2022', '2023', '2024']
# Model: sshleifer/distilbart-cnn-12-6
# Max summary length: 768
# Min summary length: 100

# %%
# Initialize summarizer model
print("Loading summarization model...")
print("This may take a few minutes on first run (downloading model)...")
print(f"Model: {MODEL_NAME} (~260MB - much smaller and more stable)")

try:
    # Use pipeline for simplicity
    summarizer = pipeline(
        "summarization",
        model=MODEL_NAME,
        device=0 if torch.cuda.is_available() else -1,  # Use GPU if available
        framework="pt"
    )
    print(f"Model loaded successfully")
    print(f"Using device: {'GPU' if torch.cuda.is_available() else 'CPU'}")
except Exception as e:
    print(f"Error loading model: {e}")
    print("Falling back to CPU...")
    summarizer = pipeline(
        "summarization",
        model=MODEL_NAME,
        device=-1,
        framework="pt"
    )
    print("Model loaded on CPU")
# Out:
# Loading summarization model...
# This may take a few minutes on first run (downloading model)...
# Model: sshleifer/distilbart-cnn-12-6 (~260MB - much smaller and more stable)
# Device set to use cpu
# Model loaded successfully
# Using device: CPU

# %%
# Helper function to chunk long texts
def chunk_text(text, max_chars=4000):
    """
    Split text into chunks that fit within token limits.
    Models typically have max_position_embeddings of 1024, so we chunk conservatively.
    """
    if len(text) <= max_chars:
        return [text]
    
    # Split by sentences (rough approximation)
    sentences = text.split('. ')
    chunks = []
    current_chunk = ""
    
    for sentence in sentences:
        if len(current_chunk) + len(sentence) + 2 <= max_chars:
            current_chunk += sentence + ". "
        else:
            if current_chunk:
                chunks.append(current_chunk.strip())
            current_chunk = sentence + ". "
    
    if current_chunk:
        chunks.append(current_chunk.strip())
    
    return chunks

# Helper function to summarize long texts
def summarize_long_text(text, summarizer, max_length=MAX_LENGTH, min_length=MIN_LENGTH):
    """
    Summarize text, handling long inputs by chunking.
    """
    chunks = chunk_text(text)
    
    if len(chunks) == 1:
        # Single chunk - summarize directly
        try:
            result = summarizer(
                text,
                max_length=max_length,
                min_length=min_length,
                do_sample=False
            )
            return result[0]['summary_text']
        except Exception as e:
            print(f"Error in summarization: {e}")
            return ""
    else:
        # Multiple chunks - summarize each and combine
        chunk_summaries = []
        for i, chunk in enumerate(chunks):
            try:
                result = summarizer(
                    chunk,
                    max_length=max_length,
                    min_length=min_length,
                    do_sample=False
                )
                chunk_summaries.append(result[0]['summary_text'])
            except Exception as e:
                print(f"Error summarizing chunk {i+1}/{len(chunks)}: {e}")
                continue
        
        # Combine chunk summaries
        combined = " ".join(chunk_summaries)
        
        # If combined is still too long, summarize again
        if len(combined) > 4000:
            try:
                result = summarizer(
                    combined,
                    max_length=max_length,
                    min_length=min_length,
                    do_sample=False
                )
                return result[0]['summary_text']
            except Exception as e:
                print(f"Error in final summarization: {e}")
                return combined
        
        return combined

print("Helper functions defined")
# Out:
# Helper functions defined

# %%
# Process documents year by year
print("MERCEDES F1 INFRINGEMENT PROFILE - ABSTRACTIVE SUMMARIZATION (VERSION 2)")

yearly_summaries = {}
yearly_stats = {}

for year in years:
    print(f"\nPROCESSING {year} - MERCEDES F1 INFRINGEMENTS")
    
    year_path = processed_base_path / year
    
    if not year_path.exists():
        print(f"Folder {year_path} does not exist")
        continue
    
    # Get all no_footer_ files
    no_footer_files = list(year_path.glob("no_footer_*.txt"))
    
    if not no_footer_files:
        print(f"No no_footer_ files found in {year}")
        continue
    
    print(f"Found {len(no_footer_files)} processed documents in {year}")
    
    # Read and combine all documents for the year
    combined_text = ""
    total_chars = 0
    processed_files = 0
    
    for file_path in no_footer_files:
        try:
            with open(file_path, 'r', encoding='utf-8') as f:
                content = f.read().strip()
                if content:
                    combined_text += content + " "
                    total_chars += len(content)
                    processed_files += 1
        except Exception as e:
            print(f"Error reading {file_path.name}: {e}")
    
    if not combined_text.strip():
        print(f"No valid content found in {year}")
        continue
    
    print(f"Processed {processed_files} files, {total_chars:,} total characters")
    
    # Generate summary using abstractive model
    print(f"\nGenerating abstractive summary for {year}...")
    print("This may take a moment...")
    
    summary = summarize_long_text(
        combined_text.strip(),
        summarizer,
        max_length=MAX_LENGTH,
        min_length=MIN_LENGTH
    )
    
    # Store results
    yearly_summaries[year] = summary
    yearly_stats[year] = {
        'files_processed': processed_files,
        'total_chars': total_chars,
        'summary_length': len(summary)
    }
    
    # Display summary
    print(f"\nABSTRACTIVE SUMMARY FOR {year}:")
    print("-" * 50)
    print(summary)
    print("-" * 50)
    print(f"Summary length: {len(summary):,} characters")
    print(f"Compression ratio: {(len(summary)/total_chars)*100:.1f}%")

print(f"\nProcessed {len(yearly_summaries)} years successfully")
# Out:
# MERCEDES F1 INFRINGEMENT PROFILE - ABSTRACTIVE SUMMARIZATION (VERSION 2)
#
# PROCESSING 2020 - MERCEDES F1 INFRINGEMENTS
# Found 11 processed documents in 2020
# Processed 11 files, 10,876 total characters
#
# Generating abstractive summary for 2020...
# This may take a moment...
# Your max_length is set to 768, but your input_length is only 677. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=338)
# ABSTRACTIVE SUMMARY FOR 2020:
# --------------------------------------------------
#  The Stewards received a petition from Aston Martin Red Bull Racing (including video footage) for them to review, in accordance with Article 14 of the FIA International Sporting Code, the following decision made by the Stewards at the 2020 Austrian Grand Prix Competition: Document 33 – 2020 Austria Grand Prix . The stewards heard from the driver of Car 44 (Lewis Hamilton) and the team representative and have reviewed video and telemetry evidences . The video footage confirmed that there have been yellow flags and green light panels at the same time and therefore conflicting signals were shown to the driver .  Lewis Hamilton received a team instruction to perform the practice start in the incorrect place . The Mercedes-AMG Petronas F1 Team is fined € 25,000 . Lewis Hamilton was penalised for not using the track at the exit of turn 10 . The driver accepted that he had not followed the instructions and further he accepted that in a race there would be a penalty . The Stewards determined that there was no advantage, as the relevant lap time was deleted according to Doc 27.1.1 .  Mercedes-AMG Petronas F1 team fined €25,000 for practice start violation . Lewis Hamilton and George Russell were involved in a tyre breach . Car 63 was fitted with front tyres that were allocated to Car 77 . Car 77 made a pit stop to change tyres only to find that the front tyres to be fitted to it, were on Car 63, so was sent out after considerable delay . This also impacted the final classification of Car 77. This type of breach has not previously been experienced in Formula One .
# --------------------------------------------------
# Summary length: 1,580 characters
# Compression ratio: 14.5%
#
# PROCESSING 2021 - MERCEDES F1 INFRINGEMENTS
# Found 16 processed documents in 2021
# Processed 16 files, 16,920 total characters
#
# Generating abstractive summary for 2021...
# This may take a moment...
# Your max_length is set to 768, but your input_length is only 234. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=117)
# ABSTRACTIVE SUMMARY FOR 2021:
# --------------------------------------------------
#  Valtteri Bottas accused of driving unnecessarily slowly in the entry to turn 9 and 10 . Lewis Hamilton disqualified from qualifying after failing to meet the requirements of Art.6.3 of the 2021 FIA Formula 1 Technical Regulations . The Stewards held a hearing on Friday following qualifying with Ron Meadows, the Competitor representative, and Simon Cole, the Chief Engineer, Trackside and from the FIA Jo Bauer, Technical Delegate and Nicholas Tombazis, Single Seater Technical Director . The FIA has examined the design of the area of the car in question and are satisfied that the design meets the intent of the regulation .  The Stewards decide that car 44 failed the test indicated in TD/011- 19 and is therefore in breach of Art 3.6.3 of the FIA Formula 1 Technical Regulations . The FIA argues that while not regulatory, the TD, like many others, describes the procedure for the test so that competitors may design cars to meet the regulations . The Competitor alleged that the fact that the car passed the test in the center section of the wing is both a mitigating factor and shows that there was no intent to breach the regulation . However, the Stewards believe that which sections failed is not relevant to the fact the wing did fail the test .  The driver of car 44, Lewis Hamilton, undid his seat belts on the in-lap at the end of the race . The driver is fined €5,000 with an additional €20,000 which is suspended through 2022 . Valtteri Bottas collided with the rear of car 4 in the braking zone to turn 1, causing an avoidable collision in turn 1 . Bottas explained that he forgot to take off the WRAO t-shirt in time during the national anthem because of the onset of rain .  Lewis Hamilton and Valtteri Bottas have been involved in several incidents this season . Hamilton was reprimanded for failing to follow the Race Director’s instruction . Bottas was fined €25,000 by the Commercial Rights Holder following the decision . Hamilton will be forced to start the race from the rear of the grid from the back of the starting grid after Bottas failed to respect a single yellow flag in the first session of the Formula One season. Bottas will be banned from qualifying for the first time since 2009 .  The following Power Unit Element has been used : 4th Internal Combustion Unit (ICE) Offence Breach of Article 23.2 a) of the FIA Formula One Sporting Regulations . Decision Drop of 10 grid positions. Decision drop of 5 grid positions . Penalty is imposed in accordance with FIA Formula 1 Sporting Regulations. No / Driver 77 - Valtteri Bottas Session Practice 1 Fact . The Stewards take this opportunity to emphasise that due to the nature of this circuit it is essential that teams communicate effectively and proactively with their drivers.
# --------------------------------------------------
# Summary length: 2,763 characters
# Compression ratio: 16.3%
#
# PROCESSING 2022 - MERCEDES F1 INFRINGEMENTS
# Found 15 processed documents in 2022
# Processed 15 files, 11,925 total characters
#
# Generating abstractive summary for 2022...
# This may take a moment...
# Your max_length is set to 768, but your input_length is only 40. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=20)
# ABSTRACTIVE SUMMARY FOR 2022:
# --------------------------------------------------
#  Lewis Hamilton was fined €500 for exceeding the pit lane speed limit by 4.5 km/h . Lewis Hamilton overtook Car 20 when the red light was displayed . Mercedes-AMG Petronas F1 Team fined £1,500 for the breach of Article 37.5 of the FIA Formula One Sporting Regulations . The Stewards took note of the precedent in relation to the 2021 Dutch Grand Prix (Max Verstappen), where no action was taken against the driver under similar but not identical circumstances .  The Competitor is fined €10,000, which will be suspended for the remainder of the season pending any further violation of the procedure, and the competitors are warned that the passes of the individuals concerned may be revoked in case of systemic violation . The Stewards heard from the driver of Car 44 (Lewis Hamilton) and team representatives, and examined video, radio communication and GPS evidence . Lewis Hamilton was issued a warning for driving unnecessarily slowly during Qualifying . The stewards took no further action for Lewis Hamilton after the collision with Fernando Alonso at turn 5 .  Stewards heard from the driver of Car 44 (Lewis Hamilton) and team representatives and examined video and radio evidence . Car 55 (Carlos Sainz) was approaching turn 13 at higher speed than Car 44 . The Stewards decided to take no further action . Hamilton admitted wearing an item of jewellery in the form of a body piercing (nose stud) during the session . Hamilton said he had been advised by his doctors not to remove it for the time being . Hamilton was fined €100 for exceeding the pit lane speed limit by 0.6 km/h .  The Stewards reviewed the video evidence and determined that the driver of car 63 braked late into turn 1 and collided with car 55, and was therefore wholly to blame for the collision . Reason The Steward reviewed the footage and said the driver was to blame, and that the collision was caused by the driver's brake brake . Reason the Stewards concluded that the crash was the result of a late-brake error by car 63, and therefore the driver is to blame. Reason the steward said the crash caused the collision.
# --------------------------------------------------
# Summary length: 2,102 characters
# Compression ratio: 17.6%
#
# PROCESSING 2023 - MERCEDES F1 INFRINGEMENTS
# Found 23 processed documents in 2023
# Processed 23 files, 19,693 total characters
#
# Generating abstractive summary for 2023...
# This may take a moment...
#
# ABSTRACTIVE SUMMARY FOR 2023:
# --------------------------------------------------
#  Mercedes-AMG Petronas F1 Team's Lewis Hamilton fined €100 for wearing of jewellery . Lewis Hamilton received a warning from the FIA for leaving the track without a justifiable reason multiple times in practice . The British driver was fined £100 for exceeding the pit lane speed limit by 0.2 km/h . The FIA will not tolerate the use of such language in FIA forums by any stakeholder . The Stewards of the 2023 Las Vegas Grand Prix will not take further action as there are medical concerns with removal of the device .  Lewis Hamilton received a 5 second time penalty for causing a collision . Hamilton was attempting to pass Perez on the inside at Turn 15 . Hamilton understeered into Perez in the wet conditions . George Russell left the track at T1 and gained a lasting advantage . Russell collided with Car 1 at Turn 12 and was on inside of Ocon at the entry to turn one . He showed some lockup and went straight entering the runoff at turn one and rejoined after turn 2, passing Ocon while doing so and gaining both the position and time .  Lewis Hamilton was fined €50,000, €25,000 of which is suspended for the remainder of the 2023 season on condition that there is no further breach of similar nature . Lewis Hamilton is fined €100 for exceeding the pit lane speed limit by 0.2 km/h . George Russell spun into the runoff at Turn 5 then rejoined the track in an unsafe manner directly in front of car 11, Perez, thus causing a collision . The Stewards heard from the driver of Car 20 (Kevin Magnussen) and reviewed video, team radio and in-car video evidence and determined Car 20 was on a slow lap .  Mercedes-AMG PETRONAS F1 Team fined €10,000 . Lewis Hamilton fined for wearing of jewellery . Mercedes team doctor requested exemption from compliance with Art. 5 on medical grounds . The Stewards have decided to take no further action as there are medical concerns with removal of the device . Driver physiotherapists/assistants of Cars 44 and 63 entered parc ferme in violation of the Post Race Interview and Podium Ceremony Procedure that was published prior to the race “for the orderly conduct of the event”  The rear skid in the area defined in the Technical Delegate’s report was outside the thresholds outlined in Article 3.5.9 e) of the FIA Formula One Technical Regulations . Car 63 unnecessarily impeded Car 16 in turn 19 at 12:41 . The Stewards heard from the driver of Car 63 (George Russell) and the team of Car 16 (Charles Leclerc), team representatives and reviewed positioning/marshalling system data, video, timing team radio and in-car video evidence .
# --------------------------------------------------
# Summary length: 2,582 characters
# Compression ratio: 13.1%
#
# PROCESSING 2024 - MERCEDES F1 INFRINGEMENTS
# Found 17 processed documents in 2024
# Processed 17 files, 16,993 total characters
#
# Generating abstractive summary for 2024...
# This may take a moment...
# Your max_length is set to 768, but your input_length is only 724. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=362)
# Your max_length is set to 768, but your input_length is only 344. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=172)
# ABSTRACTIVE SUMMARY FOR 2024:
# --------------------------------------------------
#  Lewis Hamilton is fined €5,000 for dangerous release of Car 44 . Lewis Hamilton crossed the white line at pit entry when entering the pits . The manoeuvre was not considered dangerous in any way, therefore the least severe penalty available is imposed . The following Power Unit elements have been replaced without approval of the FIA Technical Delegate during Parc Ferme . George Russell failed to slow under yellow flags after running into the runoff at Turn 2 . This was a similar case to the decision of this panel of Stewards regarding Charles Leclerc with some important differences .  Car 63 (796.5 kg) was below the minimum weight required (798.0 kg) Weight of Car 63 is disqualified from the Race classification . Car 44 (Lewis Hamilton) unnecessarily impeded Car 11 in turn 9 . Mercedes-AMG PETRONAS F1 Team is fined €5,000. The Stewards recommend that this matter be clarified in the next Drivers’ meeting and note that these penalties should not represent a binding precedent . Lewis Hamilton is fined for impeding Car 11 (Sergio Perez) and Sergio Perez for not slowing down more .  Lewis Hamilton received a drive through penalty for speeding in the pit lane during a sprint session race . The Mercedes-AMG PETRONAS F1 Team is fined €15,000 for failing to warn their driver of the fact that Car 44 was arriving on a fast lap . Lewis Hamilton was also fined for unnecessarily impeding Car 2 in Turn 11 at 20:16. The FIA transponder indicated a false start. The Stewards reviewed positioning/marshalling system data, video, timing and in-car video evidence . The driver of Car 63 failed to maintain a 10 car-length distance behind the Safety Car .  The driver left the grid although the aborted start signal was given . The FIA accepted that given this short notice it was extremely difficult if not impossible for the teams to follow the procedure prescribed in the technical directive . Tyre pressures were adjusted (pressure released) with wheels already fitted to the car in contravention to TD003. The FIA Technical Delegate stipulated that the tyre pressures while having been adjusted by the team was within the allowed parameters . The decision should not be considered as a precedent for any similar breach in the future as the circumstances are considered unique .  The team failed to cover and continued to work on the car while under Parc Ferme conditions . Normally a breach of this nature, within a competitive session would carry a sporting penalty but it is not appropriate in this case . However, this decision should not be considered as a precedent for any similar breach in the future as the circumstances are considered unique . Forcing car 77 off the track at turn 12 was not deliberate, and the driver of Car 63 was in control of the car at all times . A 5 second penalty is imposed instead of the standard 10 second penalty .
# --------------------------------------------------
# Summary length: 2,861 characters
# Compression ratio: 16.8%
#
# Processed 5 years successfully

# %%
# Generate overall consolidated summary
print("\nOVERALL CONSOLIDATED SUMMARY - ALL YEARS")

if yearly_summaries:
    # Combine all yearly summaries
    all_summaries_text = " "
    for year, summary in yearly_summaries.items():
        all_summaries_text += f"{year} Summary: {summary} "
    
    # Generate overall summary
    print("Generating overall consolidated summary...")
    print("This may take a moment...")
    
    overall_summary = summarize_long_text(
        all_summaries_text.strip(),
        summarizer,
        max_length=MAX_LENGTH,
        min_length=MIN_LENGTH
    )
    
    print("\nOVERALL MERCEDES F1 INFRINGEMENT PROFILE (ABSTRACTIVE V2):")
    print("=" * 50)
    print(overall_summary)
    print("=" * 50)
    
    # Statistics
    total_files = sum(stats['files_processed'] for stats in yearly_stats.values())
    total_chars = sum(stats['total_chars'] for stats in yearly_stats.values())
    
    print(f"\nOVERALL STATISTICS:")
    print(f"Total documents processed: {total_files}")
    print(f"Total characters analyzed: {total_chars:,}")
    print(f"Overall summary length: {len(overall_summary):,} characters")
    print(f"Overall compression ratio: {(len(overall_summary)/total_chars)*100:.1f}%")
    
    print(f"\nYEARLY BREAKDOWN:")
    for year, stats in yearly_stats.items():
        compression = (stats['summary_length']/stats['total_chars'])*100 if stats['total_chars'] > 0 else 0
        print(f"{year}: {stats['files_processed']} docs, {stats['total_chars']:,} chars -> {stats['summary_length']:,} chars ({compression:.1f}%)")
    
else:
    print("No summaries generated. Please check the input files.")
# Out:
# OVERALL CONSOLIDATED SUMMARY - ALL YEARS
# Generating overall consolidated summary...
# This may take a moment...
# Your max_length is set to 768, but your input_length is only 16. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=8)
# OVERALL MERCEDES F1 INFRINGEMENT PROFILE (ABSTRACTIVE V2):
# ==================================================
#  Mercedes-AMG Petronas F1 team fined €25,000 for practice start violation . Lewis Hamilton disqualified from qualifying after failing to meet the requirements of Art.6.3 of the 2021 FIA Formula 1 Technical Regulations . Valtteri Bottas will be banned from qualifying for the first time since 2009 . Hamilton will start the race from the rear of the grid from the back of the starting grid after Bottas failed to respect a single yellow flag in the first session of the Formula One season .  Lewis Hamilton was fined €500 for exceeding the pit lane speed limit by 4.5 km/h . Mercedes-AMG Petronas F1 Team fined £1,500 for the breach of Article 37.5 of the FIA Formula One Sporting Regulations . Hamilton admitted wearing an item of jewellery in the form of a body piercing (nose stud) during the session . Lewis Hamilton received a warning for driving unnecessarily slowly during Qualifying . The stewards took no further action for Lewis Hamilton after the collision with Fernando Alonso at turn 5 .  Mercedes team doctor requested exemption from compliance with Art. 5 on medical grounds . Lewis Hamilton crossed the white line at pit entry when entering the pits . Car 63 unnecessarily impeded Car 16 in turn 19 at 12:41 . The Stewards heard from the driver of Car 20 (Kevin Magnussen) and reviewed video, team radio and in-car video evidence and determined Car 20 was on a slow lap . The following Power Unit elements have been replaced without approval of the FIA Technical Delegate during Parc Ferme . The decision should not be considered as a precedent for any similar breach in the future .  A 5 second penalty is imposed instead of the standard 10 second penalty . The penalty is instead of a standard 10-second penalty . A 5second penalty is also imposed on penalties for a second time instead of 10 seconds . The decision was made after a penalty was awarded after a second-half penalty was given to the wrong side of the penalty line-up . CLICK HERE for all the latest from our live updates from our new World Cup 2015 news stories and videos from the World Cup in action .
# ==================================================
#
# OVERALL STATISTICS:
# Total documents processed: 82
# Total characters analyzed: 76,407
# Overall summary length: 2,085 characters
# Overall compression ratio: 2.7%
#
# YEARLY BREAKDOWN:
# 2020: 11 docs, 10,876 chars -> 1,580 chars (14.5%)
# 2021: 16 docs, 16,920 chars -> 2,763 chars (16.3%)
# 2022: 15 docs, 11,925 chars -> 2,102 chars (17.6%)
# 2023: 23 docs, 19,693 chars -> 2,582 chars (13.1%)
# 2024: 17 docs, 16,993 chars -> 2,861 chars (16.8%)

# %%
# Save results to files
print("\nSAVING RESULTS")

# Create output directory (Version 2)
output_dir = Path("distilbart_results_v2")
output_dir.mkdir(exist_ok=True)

# Save yearly summaries
for year, summary in yearly_summaries.items():
    output_file = output_dir / f"distilbart_summary_{year}.txt"
    with open(output_file, 'w', encoding='utf-8') as f:
        f.write(f"Mercedes F1 Infringement Summary - {year}\n")
        f.write("="*50 + "\n\n")
        f.write(summary)
    print(f"Saved {year} summary to {output_file}")

# Save overall summary
if yearly_summaries:
    overall_file = output_dir / "distilbart_overall_summary.txt"
    with open(overall_file, 'w', encoding='utf-8') as f:
        f.write("Mercedes F1 Infringement Profile - Overall Summary (Abstractive V2)\n")
        f.write("="*50 + "\n\n")
        f.write(overall_summary)
        f.write("\n\n" + "="*50 + "\n")
        f.write("STATISTICS\n")
        f.write("="*50 + "\n")
        total_files = sum(stats['files_processed'] for stats in yearly_stats.values())
        total_chars = sum(stats['total_chars'] for stats in yearly_stats.values())
        f.write(f"Total documents processed: {total_files}\n")
        f.write(f"Total characters analyzed: {total_chars:,}\n")
        f.write(f"Overall summary length: {len(overall_summary):,} characters\n")
        f.write(f"Overall compression ratio: {(len(overall_summary)/total_chars)*100:.1f}%\n")
    print(f"Saved overall summary to {overall_file}")

print("\nAll results saved successfully!")
print(f"Results saved in: {output_dir}")
# Out:
# SAVING RESULTS
# Saved 2020 summary to distilbart_results_v2\distilbart_summary_2020.txt
# Saved 2021 summary to distilbart_results_v2\distilbart_summary_2021.txt
# Saved 2022 summary to distilbart_results_v2\distilbart_summary_2022.txt
# Saved 2023 summary to distilbart_results_v2\distilbart_summary_2023.txt
# Saved 2024 summary to distilbart_results_v2\distilbart_summary_2024.txt
# Saved overall summary to distilbart_results_v2\distilbart_overall_summary.txt
#
# All results saved successfully!
# Results saved in: distilbart_results_v2
